# %% [markdown]
# Load the data stored in the SpectrogramDataset folder

# %%
import os
import numpy as np
import json

# --- Define paths ---
base_dir = "C:\\Users\\jorge\\Desktop\\ECG_PROJECT\\OnGoingDataset\\SpectrogramDataset"
spectrogram_dir = os.path.join(base_dir, "spectrograms")
annotations_dir = os.path.join(base_dir, "annotations")

# --- Initialize storage ---
all_specs = []
all_labels = []
all_metadata = []
record_names = []

# --- Loop through spectrogram files ---
for file in os.listdir(spectrogram_dir):
    if not file.endswith("_spec.npy"):
        continue
    
    record_name = file.replace("_spec.npy", "")
    spec_path = os.path.join(spectrogram_dir, f"{record_name}_spec.npy")
    label_path = os.path.join(annotations_dir, f"{record_name}_labels.npy")
    json_path = os.path.join(annotations_dir, f"{record_name}_annotations.json")

    # Load files
    try:
        spec = np.load(spec_path)
        labels = np.load(label_path)
        with open(json_path, "r") as f_json:
            metadata = json.load(f_json)

        # Store
        all_specs.append(spec)
        all_labels.append(labels)
        all_metadata.append(metadata)
        record_names.append(record_name)

        print(f"Loaded: {record_name} | spec: {spec.shape} | labels: {labels.shape} | waves: {list(metadata.keys())[1:]}")

    except Exception as e:
        print(f"Failed to load {record_name}: {e}")

# --- Summary ---
print(f"\nTotal loaded records: {len(all_specs)}")
# Out:
# Loaded: 100 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 101 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 102 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 103 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 104 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 105 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 106 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 107 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 108 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 109 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 10 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 110 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 111 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 112 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 113 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 114 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 115 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 116 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 117 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 118 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 119 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 11 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 120 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 121 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 122 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 123 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 124 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 125 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 126 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 127 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 128 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 129 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 12 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 130 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 131 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 132 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 133 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 134 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 135 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 136 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 137 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 138 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 139 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 13 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 140 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 141 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 142 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 143 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 144 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 145 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 146 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 147 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 148 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 149 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 14 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 150 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 151 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 152 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 153 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 154 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 155 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 156 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 157 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 158 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 159 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 15 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 160 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 161 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 162 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 163 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 164 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 165 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 166 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 167 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 168 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 169 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 16 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 170 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 171 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 172 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 173 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 174 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 175 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 176 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 177 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 178 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 179 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 17 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 180 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 181 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 182 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 183 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 184 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 185 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 186 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 187 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 188 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 189 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 18 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 190 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 191 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 192 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 193 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 194 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 195 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 196 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 197 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 198 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 199 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 19 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 1 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 200 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 20 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 21 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 22 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 23 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 24 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 25 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 26 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 27 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 28 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 29 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 2 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 30 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 31 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 32 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 33 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 34 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 35 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 36 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 37 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 38 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 39 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 3 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 40 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 41 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 42 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 43 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 44 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 45 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 46 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 47 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 48 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 49 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 4 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 50 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 51 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 52 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 53 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 54 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 55 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 56 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 57 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 58 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 59 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 5 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 60 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 61 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 62 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 63 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 64 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 65 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 66 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 67 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 68 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 69 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 6 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 70 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 71 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 72 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 73 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 74 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 75 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 76 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 77 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 78 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 79 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 7 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 80 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 81 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 82 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 83 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 84 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 85 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 86 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 87 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 88 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 89 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 8 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 90 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 91 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 92 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 93 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 94 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 95 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 96 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 97 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 98 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 99 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 9 | spec: (20, 80) | labels: (80,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
#
# Total loaded records: 200

# %%
import os
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import json
import matplotlib.pyplot as plt
import seaborn as sns

def plot_confusion_matrix(cm, class_names, epoch, save_path=None):
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=class_names,
                yticklabels=class_names)
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title(f"Confusion Matrix - Epoch {epoch}")
    
    if save_path:
        plt.savefig(save_path)
        print(f"📊 Confusion matrix saved: {save_path}")
    else:
        plt.show()
    plt.close()

def plot_training_curves(train_losses, val_accuracies):
    epochs = range(1, len(train_losses) + 1)

    fig, ax1 = plt.subplots(figsize=(8, 5))

    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Training Loss', color='tab:red')
    ax1.plot(epochs, train_losses, color='tab:red', label="Loss")
    ax1.tick_params(axis='y', labelcolor='tab:red')

    ax2 = ax1.twinx()
    ax2.set_ylabel('Validation Accuracy (%)', color='tab:blue')
    ax2.plot(epochs, val_accuracies, color='tab:blue', label="Val Accuracy")
    ax2.tick_params(axis='y', labelcolor='tab:blue')

    fig.tight_layout()
    plt.title("Training Loss & Validation Accuracy")
    plt.savefig("training_curves.png")
    print("📈 Training curves saved: training_curves.png")
    plt.close()

# === Dataset ===
class SpectrogramDataset(Dataset):
    def __init__(self, spec_list, label_list):
        self.specs = spec_list
        self.labels = label_list

    def __len__(self):
        return len(self.specs)

    def __getitem__(self, idx):
        spec = torch.tensor(self.specs[idx].T, dtype=torch.float32)  # (80, 20)
        label = torch.tensor(self.labels[idx], dtype=torch.long)     # (80,)
        return spec, label





# === Load Your Data ===
def load_dataset(base_dir):
    spectrogram_dir = os.path.join(base_dir, "spectrograms")
    annotations_dir = os.path.join(base_dir, "annotations")

    all_specs, all_labels = [], []

    for file in os.listdir(spectrogram_dir):
        if not file.endswith("_spec.npy"):
            continue

        record_name = file.replace("_spec.npy", "")
        spec_path = os.path.join(spectrogram_dir, f"{record_name}_spec.npy")
        label_path = os.path.join(annotations_dir, f"{record_name}_labels.npy")

        try:
            spec = np.load(spec_path)  # shape (20, 80)
            labels = np.load(label_path)  # shape (80,)
            all_specs.append(spec)
            all_labels.append(labels)
        except Exception as e:
            print(f"Error loading {record_name}: {e}")

    return all_specs, all_labels

from collections import defaultdict
from sklearn.metrics import confusion_matrix
import numpy as np

# %%
#Input (B, T, 20) → Linear → (B, T, 64)
        #       → Transformer → (B, T, 64)
          #     → Linear Classifier → (B, T, 4)

# === Transformer Model ===
class LatentClassifier(nn.Module):
    def  __init__(self, input_dim=20, model_dim=64, num_classes=4, nhead=, num_l10ayers=2):
        super().__init__()
        self.input_proj = nn.Linear(input_dim, model_dim)

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=model_dim,
            nhead=nhead,
            batch_first=True
        )
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)

        self.classifier = nn.Linear(model_dim, num_classes)

    def forward(self, x):  # x: (batch, seq_len, input_dim)
        x = self.input_proj(x)         # -> (batch, seq_len, model_dim)
        x = self.encoder(x)            # -> (batch, seq_len, model_dim)
        out = self.classifier(x)       # -> (batch, seq_len, num_classes)
        return out
    

import torch
import torch.nn as nn
# One alternative
class LatentClassifier_Pos(nn.Module):
    def __init__(self, input_dim=20, model_dim=64, num_classes=4, nhead=10, num_layers=2, max_len=512):
        super().__init__()

        self.input_proj = nn.Linear(input_dim, model_dim)

        # === Learnable Positional Encoding ===
        self.positional_encoding = nn.Parameter(torch.randn(1, max_len, model_dim))

        # === Transformer Encoder ===
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=model_dim,
            nhead=nhead,
            batch_first=True
        )
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)

        self.classifier = nn.Linear(model_dim, num_classes)

    def forward(self, x):  # x: (batch, seq_len, input_dim)
        B, T, _ = x.size()
        x = self.input_proj(x)                    # → (B, T, model_dim)

        # Add positional encoding (truncate or pad as needed)
        x = x + self.positional_encoding[:, :T, :]  # → (B, T, model_dim)

        x = self.encoder(x)                       # → (B, T, model_dim)
        out = self.classifier(x)                  # → (B, T, num_classes)
        return out
    
    
    
def train_one_epoch(model, dataloader, optimizer, device, num_classes=4):
    model.train()
    criterion = nn.CrossEntropyLoss()
    total_loss = 0

    for inputs, targets in dataloader:
        inputs, targets = inputs.to(device), targets.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs.view(-1, num_classes), targets.view(-1))
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    print(f"✅ Training Loss: {total_loss / len(dataloader):.4f}")
    return total_loss / len(dataloader);
# Out:
#   File "<ipython-input-38-0ff2c9e7a886>", line 7
#     def  __init__(self, input_dim=20, model_dim=64, num_classes=4, nhead=, num_l10ayers=2):
#                                                                          ^
# SyntaxError: invalid syntax

# %%
from collections import defaultdict
from sklearn.metrics import confusion_matrix

def evaluate_model(model, dataloader, device, num_classes=4,  epoch=0):
    model.eval()
    all_preds = []
    all_targets = []

    with torch.no_grad():
        for inputs, targets in dataloader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            preds = outputs.argmax(dim=-1)

            all_preds.append(preds.cpu().view(-1))
            all_targets.append(targets.cpu().view(-1))

    preds_flat = torch.cat(all_preds).numpy()
    targets_flat = torch.cat(all_targets).numpy()

    # Accuracy
    class_correct = defaultdict(int)
    class_total = defaultdict(int)

    for c in range(num_classes):
        mask = targets_flat == c
        class_total[c] += mask.sum()
        class_correct[c] += (preds_flat[mask] == c).sum()

    total_correct = (preds_flat == targets_flat).sum()
    total_count = len(targets_flat)

    print(f"\n📊 Validation Accuracy Report")
    print(f"  Overall Accuracy: {100 * total_correct / total_count:.2f}%")

    for c in range(num_classes):
        if class_total[c] > 0:
            acc = 100 * class_correct[c] / class_total[c]
            label_name = ["background", "p_wave", "qrs", "t_wave"][c]
            print(f"  Class {c} ({label_name}): {acc:.2f}%")
        else:
            print(f"  Class {c}: No samples")

    # Confusion matrix
    cm = confusion_matrix(targets_flat, preds_flat, labels=list(range(num_classes)))
    print("\n  Confusion Matrix (rows = true, cols = predicted):")
    print(cm)
        # Plot heatmap
    class_names = ["background", "p_wave", "qrs", "t_wave"]
    #plot_confusion_matrix(cm, class_names, epoch, save_path=f"confusion_matrix_epoch_{epoch}.png")

    return 100 * total_correct / total_count  # <== return this value

# %%
def save_model(model, path="best_model.pt"):
    torch.save(model.state_dict(), path)
    print(f"📦 Model saved to: {path}")

# %%
if __name__ == "__main__":
    base_dir = r"C:\Users\jorge\Desktop\ECG_PROJECT\OnGoingDataset\SpectrogramDataset"
    specs, labels = load_dataset(base_dir)

    # Split into train/val
    from sklearn.model_selection import train_test_split
    train_specs, val_specs, train_labels, val_labels = train_test_split(
        specs, labels, test_size=0.2, random_state=42, shuffle=True
    )

    train_dataset = SpectrogramDataset(train_specs, train_labels)
    val_dataset = SpectrogramDataset(val_specs, val_labels)

    train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    model = LatentClassifier().to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

    best_accuracy = 0.0
    epochs_without_improvement = 0
    patience = 10  # Stop if no improvement after 3 epochs
    train_losses = []
    val_accuracies = []
    
    for epoch in range(500):
        print(f"\n🔁 Epoch {epoch + 1}")
        loss = train_one_epoch(model, train_loader, optimizer, device)
        val_accuracy = evaluate_model(model, val_loader, device, epoch=epoch + 1)

        train_losses.append(loss)
        val_accuracies.append(val_accuracy)
        # Early stopping check
        if val_accuracy > best_accuracy:
            best_accuracy = val_accuracy
            epochs_without_improvement = 0
            save_model(model, "best_model.pt")
        else:
            epochs_without_improvement += 1
            print(f"⏳ No improvement for {epochs_without_improvement} epoch(s).")

        if epochs_without_improvement >= patience:
            print(f"\n🛑 Early stopping: no improvement after {patience} epochs.")
            break

plot_training_curves(train_losses, val_accuracies)
# Out:
# 🔁 Epoch 1
# ✅ Training Loss: 1.2232
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 55.09%
#   Class 0 (background): 80.39%
#   Class 1 (p_wave): 0.00%
#   Class 2 (qrs): 65.51%
#   Class 3 (t_wave): 29.33%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1148    0  105  175]
#  [ 327    0    0   56]
#  [ 133    1  376   64]
#  [ 555    0   21  239]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 2
# ✅ Training Loss: 1.0413
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 58.12%
#   Class 0 (background): 80.60%
#   Class 1 (p_wave): 0.00%
#   Class 2 (qrs): 79.44%
#   Class 3 (t_wave): 31.04%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1151    0  130  147]
#  [ 341    0    3   39]
#  [ 110    1  456    7]
#  [ 531    0   31  253]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 3
# ✅ Training Loss: 0.9881
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 59.69%
#   Class 0 (background): 81.65%
#   Class 1 (p_wave): 0.00%
#   Class 2 (qrs): 81.88%
#   Class 3 (t_wave): 33.62%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1166    0  131  131]
#  [ 336    0    3   44]
#  [  96    1  470    7]
#  [ 502    1   38  274]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 4
# ✅ Training Loss: 0.9595
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 61.44%
#   Class 0 (background): 77.94%
#   Class 1 (p_wave): 0.00%
#   Class 2 (qrs): 82.93%
#   Class 3 (t_wave): 46.26%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1113    0  124  191]
#  [ 301    0    3   79]
#  [  82    0  476   16]
#  [ 398    1   39  377]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 5
# ✅ Training Loss: 0.9309
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 62.75%
#   Class 0 (background): 79.48%
#   Class 1 (p_wave): 0.00%
#   Class 2 (qrs): 83.80%
#   Class 3 (t_wave): 48.10%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1135    1  111  181]
#  [ 301    0    3   79]
#  [  80    1  481   12]
#  [ 381    2   40  392]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 6
# ✅ Training Loss: 0.9091
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 65.56%
#   Class 0 (background): 75.63%
#   Class 1 (p_wave): 6.01%
#   Class 2 (qrs): 85.89%
#   Class 3 (t_wave): 61.60%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1080    9  113  226]
#  [ 230   23    5  125]
#  [  42    4  493   35]
#  [ 260    9   44  502]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 7
# ✅ Training Loss: 0.8909
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 64.97%
#   Class 0 (background): 74.65%
#   Class 1 (p_wave): 8.36%
#   Class 2 (qrs): 85.37%
#   Class 3 (t_wave): 60.25%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1066   14  108  240]
#  [ 220   32    2  129]
#  [  48    5  490   31]
#  [ 274   10   40  491]]
# ⏳ No improvement for 1 epoch(s).
#
# 🔁 Epoch 8
# ✅ Training Loss: 0.8750
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 65.09%
#   Class 0 (background): 78.29%
#   Class 1 (p_wave): 14.36%
#   Class 2 (qrs): 85.37%
#   Class 3 (t_wave): 51.53%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1118   23  103  184]
#  [ 255   55    1   72]
#  [  64    7  490   13]
#  [ 343   18   34  420]]
# ⏳ No improvement for 2 epoch(s).
#
# 🔁 Epoch 9
# ✅ Training Loss: 0.8567
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 66.59%
#   Class 0 (background): 76.12%
#   Class 1 (p_wave): 16.45%
#   Class 2 (qrs): 87.63%
#   Class 3 (t_wave): 58.65%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1087   30  107  204]
#  [ 231   63    1   88]
#  [  42    8  503   21]
#  [ 279   19   39  478]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 10
# ✅ Training Loss: 0.8458
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 67.06%
#   Class 0 (background): 75.70%
#   Class 1 (p_wave): 17.23%
#   Class 2 (qrs): 89.72%
#   Class 3 (t_wave): 59.39%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1081   31  110  206]
#  [ 228   66    2   87]
#  [  32    6  515   21]
#  [ 270   20   41  484]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 11
# ✅ Training Loss: 0.8304
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 66.38%
#   Class 0 (background): 79.41%
#   Class 1 (p_wave): 15.93%
#   Class 2 (qrs): 87.98%
#   Class 3 (t_wave): 52.02%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1134   22  107  165]
#  [ 264   61    1   57]
#  [  46    7  505   16]
#  [ 332   20   39  424]]
# ⏳ No improvement for 1 epoch(s).
#
# 🔁 Epoch 12
# ✅ Training Loss: 0.8212
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 67.47%
#   Class 0 (background): 75.56%
#   Class 1 (p_wave): 23.50%
#   Class 2 (qrs): 89.55%
#   Class 3 (t_wave): 58.40%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1079   36  110  203]
#  [ 216   90    1   76]
#  [  34    9  514   17]
#  [ 265   27   47  476]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 13
# ✅ Training Loss: 0.8102
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 67.12%
#   Class 0 (background): 72.06%
#   Class 1 (p_wave): 22.19%
#   Class 2 (qrs): 90.07%
#   Class 3 (t_wave): 63.44%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1029   39  116  244]
#  [ 193   85    1  104]
#  [  27    8  517   22]
#  [ 222   28   48  517]]
# ⏳ No improvement for 1 epoch(s).
#
# 🔁 Epoch 14
# ✅ Training Loss: 0.7999
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 68.31%
#   Class 0 (background): 73.25%
#   Class 1 (p_wave): 32.11%
#   Class 2 (qrs): 91.46%
#   Class 3 (t_wave): 60.37%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1046   59  117  206]
#  [ 190  123    1   69]
#  [  22   12  525   15]
#  [ 232   39   52  492]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 15
# ✅ Training Loss: 0.7988
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 68.19%
#   Class 0 (background): 70.94%
#   Class 1 (p_wave): 46.48%
#   Class 2 (qrs): 89.55%
#   Class 3 (t_wave): 58.53%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1013  119  114  182]
#  [ 164  178    1   40]
#  [  28   17  514   15]
#  [ 218   79   41  477]]
# ⏳ No improvement for 1 epoch(s).
#
# 🔁 Epoch 16
# ✅ Training Loss: 0.7898
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 67.94%
#   Class 0 (background): 75.00%
#   Class 1 (p_wave): 38.12%
#   Class 2 (qrs): 91.81%
#   Class 3 (t_wave): 52.76%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1071   76  120  161]
#  [ 205  146    1   31]
#  [  27   11  527    9]
#  [ 273   56   56  430]]
# ⏳ No improvement for 2 epoch(s).
#
# 🔁 Epoch 17
# ✅ Training Loss: 0.7814
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 68.06%
#   Class 0 (background): 76.47%
#   Class 1 (p_wave): 31.85%
#   Class 2 (qrs): 91.64%
#   Class 3 (t_wave): 53.74%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1092   56  117  163]
#  [ 228  122    1   32]
#  [  30    8  526   10]
#  [ 279   42   56  438]]
# ⏳ No improvement for 3 epoch(s).
#
# 🔁 Epoch 18
# ✅ Training Loss: 0.7733
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 67.72%
#   Class 0 (background): 75.49%
#   Class 1 (p_wave): 29.24%
#   Class 2 (qrs): 90.59%
#   Class 3 (t_wave): 56.07%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1078   53  115  182]
#  [ 223  112    1   47]
#  [  35    6  520   13]
#  [ 278   31   49  457]]
# ⏳ No improvement for 4 epoch(s).
#
# 🔁 Epoch 19
# ✅ Training Loss: 0.7686
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 68.41%
#   Class 0 (background): 72.69%
#   Class 1 (p_wave): 33.68%
#   Class 2 (qrs): 90.24%
#   Class 3 (t_wave): 61.84%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1038   62  113  215]
#  [ 196  129    1   57]
#  [  24    5  518   27]
#  [ 228   40   43  504]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 20
# ✅ Training Loss: 0.7614
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 68.59%
#   Class 0 (background): 75.35%
#   Class 1 (p_wave): 39.43%
#   Class 2 (qrs): 89.72%
#   Class 3 (t_wave): 55.58%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1076   78  111  163]
#  [ 204  151    0   28]
#  [  31   12  515   16]
#  [ 269   49   44  453]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 21
# ✅ Training Loss: 0.7508
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 69.06%
#   Class 0 (background): 72.13%
#   Class 1 (p_wave): 40.47%
#   Class 2 (qrs): 89.72%
#   Class 3 (t_wave): 62.58%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1030   73  114  211]
#  [ 186  155    0   42]
#  [  20   12  515   27]
#  [ 217   47   41  510]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 22
# ✅ Training Loss: 0.7438
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 69.38%
#   Class 0 (background): 72.90%
#   Class 1 (p_wave): 36.81%
#   Class 2 (qrs): 89.90%
#   Class 3 (t_wave): 64.05%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1041   65  114  208]
#  [ 182  141    1   59]
#  [  24    9  516   25]
#  [ 212   37   44  522]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 23
# ✅ Training Loss: 0.7394
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 69.38%
#   Class 0 (background): 73.81%
#   Class 1 (p_wave): 44.91%
#   Class 2 (qrs): 91.11%
#   Class 3 (t_wave): 57.79%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1054   86  115  173]
#  [ 186  172    1   24]
#  [  20   12  523   19]
#  [ 242   54   48  471]]
# ⏳ No improvement for 1 epoch(s).
#
# 🔁 Epoch 24
# ✅ Training Loss: 0.7355
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 69.81%
#   Class 0 (background): 70.31%
#   Class 1 (p_wave): 43.86%
#   Class 2 (qrs): 91.64%
#   Class 3 (t_wave): 65.77%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1004   72  117  235]
#  [ 165  168    1   49]
#  [  12   10  526   26]
#  [ 189   41   49  536]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 25
# ✅ Training Loss: 0.7278
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 69.16%
#   Class 0 (background): 73.60%
#   Class 1 (p_wave): 46.21%
#   Class 2 (qrs): 90.59%
#   Class 3 (t_wave): 57.06%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1051   83  116  178]
#  [ 184  177    1   21]
#  [  28   13  520   13]
#  [ 252   51   47  465]]
# ⏳ No improvement for 1 epoch(s).
#
# 🔁 Epoch 26
# ✅ Training Loss: 0.7245
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 69.09%
#   Class 0 (background): 74.37%
#   Class 1 (p_wave): 33.68%
#   Class 2 (qrs): 90.94%
#   Class 3 (t_wave): 61.10%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1062   56  116  194]
#  [ 207  129    1   46]
#  [  27    4  522   21]
#  [ 236   30   51  498]]
# ⏳ No improvement for 2 epoch(s).
#
# 🔁 Epoch 27
# ✅ Training Loss: 0.7247
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 70.03%
#   Class 0 (background): 72.76%
#   Class 1 (p_wave): 46.21%
#   Class 2 (qrs): 90.24%
#   Class 3 (t_wave): 62.21%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1039   77  114  198]
#  [ 173  177    1   32]
#  [  19   10  518   27]
#  [ 225   43   40  507]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 28
# ✅ Training Loss: 0.7127
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 69.97%
#   Class 0 (background): 69.96%
#   Class 1 (p_wave): 41.25%
#   Class 2 (qrs): 92.16%
#   Class 3 (t_wave): 67.85%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[999  67 123 239]
#  [171 158   1  53]
#  [ 12   7 529  26]
#  [181  33  48 553]]
# ⏳ No improvement for 1 epoch(s).
#
# 🔁 Epoch 29
# ✅ Training Loss: 0.7096
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 69.16%
#   Class 0 (background): 72.41%
#   Class 1 (p_wave): 34.99%
#   Class 2 (qrs): 91.64%
#   Class 3 (t_wave): 63.68%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1034   57  120  217]
#  [ 209  134    1   39]
#  [  19    4  526   25]
#  [ 216   29   51  519]]
# ⏳ No improvement for 2 epoch(s).
#
# 🔁 Epoch 30
# ✅ Training Loss: 0.7065
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 69.97%
#   Class 0 (background): 71.78%
#   Class 1 (p_wave): 49.87%
#   Class 2 (qrs): 92.16%
#   Class 3 (t_wave): 60.61%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1025   83  120  200]
#  [ 164  191    1   27]
#  [  15   10  529   20]
#  [ 223   47   51  494]]
# ⏳ No improvement for 3 epoch(s).
#
# 🔁 Epoch 31
# ✅ Training Loss: 0.7006
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 70.31%
#   Class 0 (background): 71.08%
#   Class 1 (p_wave): 46.21%
#   Class 2 (qrs): 92.16%
#   Class 3 (t_wave): 64.91%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1015   75  120  218]
#  [ 167  177    1   38]
#  [  13    8  529   24]
#  [ 205   34   47  529]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 32
# ✅ Training Loss: 0.6950
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 70.31%
#   Class 0 (background): 72.41%
#   Class 1 (p_wave): 52.22%
#   Class 2 (qrs): 91.64%
#   Class 3 (t_wave): 60.12%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1034   86  118  190]
#  [ 161  200    1   21]
#  [  20   13  526   15]
#  [ 223   52   50  490]]
# ⏳ No improvement for 1 epoch(s).
#
# 🔁 Epoch 33
# ✅ Training Loss: 0.6939
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 70.75%
#   Class 0 (background): 63.87%
#   Class 1 (p_wave): 56.40%
#   Class 2 (qrs): 91.29%
#   Class 3 (t_wave): 75.09%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[912 104 120 292]
#  [115 216   1  51]
#  [  6  11 524  33]
#  [119  42  42 612]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 34
# ✅ Training Loss: 0.6888
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 69.72%
#   Class 0 (background): 72.83%
#   Class 1 (p_wave): 44.91%
#   Class 2 (qrs): 91.46%
#   Class 3 (t_wave): 60.61%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1040   81  117  190]
#  [ 188  172    1   22]
#  [  21   10  525   18]
#  [ 233   39   49  494]]
# ⏳ No improvement for 1 epoch(s).
#
# 🔁 Epoch 35
# ✅ Training Loss: 0.6860
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 70.19%
#   Class 0 (background): 70.45%
#   Class 1 (p_wave): 46.48%
#   Class 2 (qrs): 92.33%
#   Class 3 (t_wave): 65.28%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1006   81  120  221]
#  [ 174  178    1   30]
#  [  15   10  530   19]
#  [ 192   41   50  532]]
# ⏳ No improvement for 2 epoch(s).
#
# 🔁 Epoch 36
# ✅ Training Loss: 0.6808
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 70.59%
#   Class 0 (background): 72.76%
#   Class 1 (p_wave): 50.39%
#   Class 2 (qrs): 92.68%
#   Class 3 (t_wave): 60.74%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1039   85  120  184]
#  [ 171  193    1   18]
#  [  16   10  532   16]
#  [ 225   43   52  495]]
# ⏳ No improvement for 3 epoch(s).
#
# 🔁 Epoch 37
# ✅ Training Loss: 0.6709
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 70.97%
#   Class 0 (background): 70.59%
#   Class 1 (p_wave): 52.48%
#   Class 2 (qrs): 91.99%
#   Class 3 (t_wave): 65.52%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1008   92  117  211]
#  [ 157  201    1   24]
#  [  17   10  528   19]
#  [ 186   47   48  534]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 38
# ✅ Training Loss: 0.6728
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 70.75%
#   Class 0 (background): 69.61%
#   Class 1 (p_wave): 57.96%
#   Class 2 (qrs): 91.29%
#   Class 3 (t_wave): 64.29%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[994 105 118 211]
#  [143 222   1  17]
#  [ 12  15 524  23]
#  [193  55  43 524]]
# ⏳ No improvement for 1 epoch(s).
#
# 🔁 Epoch 39
# ✅ Training Loss: 0.6717
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 71.44%
#   Class 0 (background): 69.47%
#   Class 1 (p_wave): 53.00%
#   Class 2 (qrs): 91.11%
#   Class 3 (t_wave): 69.69%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[992  80 116 240]
#  [145 203   1  34]
#  [ 12  10 523  29]
#  [163  41  43 568]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 40
# ✅ Training Loss: 0.6614
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 71.22%
#   Class 0 (background): 69.82%
#   Class 1 (p_wave): 55.87%
#   Class 2 (qrs): 91.11%
#   Class 3 (t_wave): 66.87%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[997  95 119 217]
#  [142 214   1  26]
#  [ 11  13 523  27]
#  [179  47  44 545]]
# ⏳ No improvement for 1 epoch(s).
#
# 🔁 Epoch 41
# ✅ Training Loss: 0.6641
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 71.44%
#   Class 0 (background): 68.91%
#   Class 1 (p_wave): 54.83%
#   Class 2 (qrs): 91.81%
#   Class 3 (t_wave): 69.33%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[984  93 117 234]
#  [143 210   1  29]
#  [  9  11 527  27]
#  [163  40  47 565]]
# ⏳ No improvement for 2 epoch(s).
#
# 🔁 Epoch 42
# ✅ Training Loss: 0.6571
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 70.88%
#   Class 0 (background): 70.38%
#   Class 1 (p_wave): 54.31%
#   Class 2 (qrs): 92.33%
#   Class 3 (t_wave): 64.42%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1005   92  121  210]
#  [ 150  208    1   24]
#  [  12   14  530   18]
#  [ 198   45   47  525]]
# ⏳ No improvement for 3 epoch(s).
#
# 🔁 Epoch 43
# ✅ Training Loss: 0.6518
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 71.19%
#   Class 0 (background): 69.05%
#   Class 1 (p_wave): 53.00%
#   Class 2 (qrs): 92.16%
#   Class 3 (t_wave): 68.71%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[986  89 120 233]
#  [145 203   1  34]
#  [  9  13 529  23]
#  [169  38  48 560]]
# ⏳ No improvement for 4 epoch(s).
#
# 🔁 Epoch 44
# ✅ Training Loss: 0.6512
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 71.50%
#   Class 0 (background): 68.35%
#   Class 1 (p_wave): 48.56%
#   Class 2 (qrs): 92.68%
#   Class 3 (t_wave): 72.88%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[976  78 118 256]
#  [154 186   1  42]
#  [ 11   8 532  23]
#  [145  30  46 594]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 45
# ✅ Training Loss: 0.6498
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 71.44%
#   Class 0 (background): 71.29%
#   Class 1 (p_wave): 51.44%
#   Class 2 (qrs): 92.33%
#   Class 3 (t_wave): 66.38%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1018   84  120  206]
#  [ 159  197    2   25]
#  [  14   10  530   20]
#  [ 191   34   49  541]]
# ⏳ No improvement for 1 epoch(s).
#
# 🔁 Epoch 46
# ✅ Training Loss: 0.6465
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 71.16%
#   Class 0 (background): 70.24%
#   Class 1 (p_wave): 51.17%
#   Class 2 (qrs): 92.51%
#   Class 3 (t_wave): 67.12%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1003   81  123  221]
#  [ 152  196    2   33]
#  [  13    7  531   23]
#  [ 183   35   50  547]]
# ⏳ No improvement for 2 epoch(s).
#
# 🔁 Epoch 47
# ✅ Training Loss: 0.6459
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 71.25%
#   Class 0 (background): 70.17%
#   Class 1 (p_wave): 51.44%
#   Class 2 (qrs): 93.03%
#   Class 3 (t_wave): 67.12%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1002   80  123  223]
#  [ 157  197    1   28]
#  [   9    8  534   23]
#  [ 188   32   48  547]]
# ⏳ No improvement for 3 epoch(s).
#
# 🔁 Epoch 48
# ✅ Training Loss: 0.6464
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 71.06%
#   Class 0 (background): 71.36%
#   Class 1 (p_wave): 55.35%
#   Class 2 (qrs): 91.81%
#   Class 3 (t_wave): 63.31%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1019   96  119  194]
#  [ 151  212    1   19]
#  [  15   13  527   19]
#  [ 206   47   46  516]]
# ⏳ No improvement for 4 epoch(s).
#
# 🔁 Epoch 49
# ✅ Training Loss: 0.6380
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 71.72%
#   Class 0 (background): 67.16%
#   Class 1 (p_wave): 58.49%
#   Class 2 (qrs): 92.68%
#   Class 3 (t_wave): 71.17%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[959  97 124 248]
#  [127 224   1  31]
#  [  6  10 532  26]
#  [141  44  50 580]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 50
# ✅ Training Loss: 0.6374
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 71.38%
#   Class 0 (background): 69.82%
#   Class 1 (p_wave): 62.66%
#   Class 2 (qrs): 93.03%
#   Class 3 (t_wave): 62.94%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[997 111 124 196]
#  [123 240   1  19]
#  [ 10  13 534  17]
#  [190  60  52 513]]
# ⏳ No improvement for 1 epoch(s).
#
# 🔁 Epoch 51
# ✅ Training Loss: 0.6288
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 71.12%
#   Class 0 (background): 70.17%
#   Class 1 (p_wave): 47.78%
#   Class 2 (qrs): 92.68%
#   Class 3 (t_wave): 68.59%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1002   71  120  235]
#  [ 164  183    1   35]
#  [  13    8  532   21]
#  [ 180   28   48  559]]
# ⏳ No improvement for 2 epoch(s).
#
# 🔁 Epoch 52
# ✅ Training Loss: 0.6238
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 72.09%
#   Class 0 (background): 68.14%
#   Class 1 (p_wave): 59.01%
#   Class 2 (qrs): 92.16%
#   Class 3 (t_wave): 71.04%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[973  97 118 240]
#  [127 226   1  29]
#  [ 11   9 529  25]
#  [151  40  45 579]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 53
# ✅ Training Loss: 0.6232
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 70.69%
#   Class 0 (background): 72.13%
#   Class 1 (p_wave): 55.35%
#   Class 2 (qrs): 91.11%
#   Class 3 (t_wave): 60.98%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1030   96  116  186]
#  [ 156  212    0   15]
#  [  22   12  523   17]
#  [ 227   43   48  497]]
# ⏳ No improvement for 1 epoch(s).
#
# 🔁 Epoch 54
# ✅ Training Loss: 0.6202
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 71.25%
#   Class 0 (background): 69.96%
#   Class 1 (p_wave): 51.17%
#   Class 2 (qrs): 92.16%
#   Class 3 (t_wave): 68.22%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[999  86 119 224]
#  [154 196   2  31]
#  [ 16   7 529  22]
#  [174  37  48 556]]
# ⏳ No improvement for 2 epoch(s).
#
# 🔁 Epoch 55
# ✅ Training Loss: 0.6185
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 71.69%
#   Class 0 (background): 67.51%
#   Class 1 (p_wave): 61.10%
#   Class 2 (qrs): 92.16%
#   Class 3 (t_wave): 69.57%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[964 117 124 223]
#  [126 234   1  22]
#  [  9  13 529  23]
#  [147  56  45 567]]
# ⏳ No improvement for 3 epoch(s).
#
# 🔁 Epoch 56
# ✅ Training Loss: 0.6193
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 71.53%
#   Class 0 (background): 70.94%
#   Class 1 (p_wave): 53.00%
#   Class 2 (qrs): 92.68%
#   Class 3 (t_wave): 66.38%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1013   86  122  207]
#  [ 155  203    2   23]
#  [  15    8  532   19]
#  [ 193   31   50  541]]
# ⏳ No improvement for 4 epoch(s).
#
# 🔁 Epoch 57
# ✅ Training Loss: 0.6126
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 71.69%
#   Class 0 (background): 67.09%
#   Class 1 (p_wave): 53.52%
#   Class 2 (qrs): 92.68%
#   Class 3 (t_wave): 73.50%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[958  84 125 261]
#  [137 205   1  40]
#  [ 10   7 532  25]
#  [133  32  51 599]]
# ⏳ No improvement for 5 epoch(s).
#
# 🔁 Epoch 58
# ✅ Training Loss: 0.6087
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 71.31%
#   Class 0 (background): 69.96%
#   Class 1 (p_wave): 57.96%
#   Class 2 (qrs): 91.46%
#   Class 3 (t_wave): 65.77%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[999 106 118 205]
#  [140 222   1  20]
#  [ 15  13 525  21]
#  [182  50  47 536]]
# ⏳ No improvement for 6 epoch(s).
#
# 🔁 Epoch 59
# ✅ Training Loss: 0.6051
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 71.53%
#   Class 0 (background): 70.94%
#   Class 1 (p_wave): 56.66%
#   Class 2 (qrs): 92.86%
#   Class 3 (t_wave): 64.54%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[1013   95  119  201]
#  [ 142  217    2   22]
#  [  17    7  533   17]
#  [ 201   40   48  526]]
# ⏳ No improvement for 7 epoch(s).
#
# 🔁 Epoch 60
# ✅ Training Loss: 0.6017
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 71.84%
#   Class 0 (background): 68.98%
#   Class 1 (p_wave): 61.62%
#   Class 2 (qrs): 92.16%
#   Class 3 (t_wave): 67.36%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[985 108 122 213]
#  [125 236   1  21]
#  [ 15  11 529  19]
#  [171  46  49 549]]
# ⏳ No improvement for 8 epoch(s).
#
# 🔁 Epoch 61
# ✅ Training Loss: 0.5975
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 71.62%
#   Class 0 (background): 69.75%
#   Class 1 (p_wave): 55.09%
#   Class 2 (qrs): 91.11%
#   Class 3 (t_wave): 68.96%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[996  96 118 218]
#  [144 211   1  27]
#  [ 22   9 523  20]
#  [175  34  44 562]]
# ⏳ No improvement for 9 epoch(s).
#
# 🔁 Epoch 62
# ✅ Training Loss: 0.6012
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 72.06%
#   Class 0 (background): 68.35%
#   Class 1 (p_wave): 62.14%
#   Class 2 (qrs): 92.16%
#   Class 3 (t_wave): 69.08%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[976 107 120 225]
#  [118 238   1  26]
#  [ 14   9 529  22]
#  [171  33  48 563]]
# ⏳ No improvement for 10 epoch(s).
#
# 🛑 Early stopping: no improvement after 10 epochs.
# 📈 Training curves saved: training_curves.png
