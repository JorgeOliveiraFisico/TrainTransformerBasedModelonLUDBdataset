# %% [markdown]
# Load the data stored in the SpectrogramDataset folder

# %%
import os
import numpy as np
import json

# --- Define paths ---
base_dir = "C:\\Users\\jorge\\Desktop\\ECG_PROJECT\\OnGoingDataset\\SpectrogramDataset\\"
spectrogram_dir = os.path.join(base_dir, "spectrograms")
annotations_dir = os.path.join(base_dir, "annotations")

# --- Initialize storage ---
all_specs = []
all_labels = []
all_metadata = []
record_names = []

# --- Loop through spectrogram files ---
for file in os.listdir(spectrogram_dir):
    if not file.endswith("_spec.npy"):
        continue
    
    record_name = file.replace("_spec.npy", "")
    spec_path = os.path.join(spectrogram_dir, f"{record_name}_spec.npy")
    label_path = os.path.join(annotations_dir, f"{record_name}_labels.npy")
    json_path = os.path.join(annotations_dir, f"{record_name}_annotations.json")

    # Load files
    try:
        spec = np.load(spec_path)
        labels = np.load(label_path)
        with open(json_path, "r") as f_json:
            metadata = json.load(f_json)

        # Store
        all_specs.append(spec)
        all_labels.append(labels)
        all_metadata.append(metadata)
        record_names.append(record_name)

        print(f"Loaded: {record_name} | spec: {spec.shape} | labels: {labels.shape} | waves: {list(metadata.keys())[1:]}")

    except Exception as e:
        print(f"Failed to load {record_name}: {e}")

# --- Summary ---
print(f"\nTotal loaded records: {len(all_specs)}")
# Out:
# Loaded: 100 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 101 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 102 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 103 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 104 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 105 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 106 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 107 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 108 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 109 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 10 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 110 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 111 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 112 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 113 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 114 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 115 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 116 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 117 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 118 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 119 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 11 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 120 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 121 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 122 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 123 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 124 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 125 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 126 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 127 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 128 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 129 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 12 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 130 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 131 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 132 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 133 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 134 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 135 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 136 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 137 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 138 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 139 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 13 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 140 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 141 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 142 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 143 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 144 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 145 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 146 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 147 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 148 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 149 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 14 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 150 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 151 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 152 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 153 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 154 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 155 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 156 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 157 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 158 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 159 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 15 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 160 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 161 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 162 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 163 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 164 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 165 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 166 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 167 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 168 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 169 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 16 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 170 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 171 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 172 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 173 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 174 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 175 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 176 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 177 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 178 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 179 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 17 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 180 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 181 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 182 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 183 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 184 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 185 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 186 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 187 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 188 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 189 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 18 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 190 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 191 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 192 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 193 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 194 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 195 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 196 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 197 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 198 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 199 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 19 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 1 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 200 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 20 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 21 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 22 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 23 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 24 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 25 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 26 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 27 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 28 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 29 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 2 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 30 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 31 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 32 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 33 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 34 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 35 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 36 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 37 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 38 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 39 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 3 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 40 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 41 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 42 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 43 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 44 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 45 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 46 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 47 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 48 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 49 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 4 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 50 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 51 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 52 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 53 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 54 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 55 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 56 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 57 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 58 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 59 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 5 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 60 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 61 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 62 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 63 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 64 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 65 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 66 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 67 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 68 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 69 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 6 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 70 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 71 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 72 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 73 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 74 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 75 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 76 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 77 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 78 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 79 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 7 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 80 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 81 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 82 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 83 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 84 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 85 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 86 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 87 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 88 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 89 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 8 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 90 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 91 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 92 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 93 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 94 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 95 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 96 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 97 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 98 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 99 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
# Loaded: 9 | spec: (40, 2500) | labels: (2500,) | waves: ['p_waves', 'qrs_complexes', 't_waves']
#
# Total loaded records: 200

# %%
import os
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import json
import matplotlib.pyplot as plt
import seaborn as sns

def plot_confusion_matrix(cm, class_names, epoch, save_path=None):
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=class_names,
                yticklabels=class_names)
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title(f"Confusion Matrix - Epoch {epoch}")
    
    if save_path:
        plt.savefig(save_path)
        print(f"📊 Confusion matrix saved: {save_path}")
    else:
        plt.show()
    plt.close()

def plot_training_curves(train_losses, val_accuracies):
    epochs = range(1, len(train_losses) + 1)

    fig, ax1 = plt.subplots(figsize=(8, 5))

    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Training Loss', color='tab:red')
    ax1.plot(epochs, train_losses, color='tab:red', label="Loss")
    ax1.tick_params(axis='y', labelcolor='tab:red')

    ax2 = ax1.twinx()
    ax2.set_ylabel('Validation Accuracy (%)', color='tab:blue')
    ax2.plot(epochs, val_accuracies, color='tab:blue', label="Val Accuracy")
    ax2.tick_params(axis='y', labelcolor='tab:blue')

    fig.tight_layout()
    plt.title("Training Loss & Validation Accuracy")
    plt.savefig("training_curves.png")
    print("📈 Training curves saved: training_curves.png")
    plt.close()

# === Dataset ===
class SpectrogramDataset(Dataset):
    def __init__(self, spec_list, label_list):
        self.specs = spec_list
        self.labels = label_list

    def __len__(self):
        return len(self.specs)

    def __getitem__(self, idx):
        spec = torch.tensor(self.specs[idx].T, dtype=torch.float32)  # (80, 20)
        label = torch.tensor(self.labels[idx], dtype=torch.long)     # (80,)
        return spec, label





# === Load Your Data ===
def load_dataset(base_dir):
    spectrogram_dir = os.path.join(base_dir, "spectrograms")
    annotations_dir = os.path.join(base_dir, "annotations")

    all_specs, all_labels = [], []

    for file in os.listdir(spectrogram_dir):
        if not file.endswith("_spec.npy"):
            continue

        record_name = file.replace("_spec.npy", "")
        spec_path = os.path.join(spectrogram_dir, f"{record_name}_spec.npy")
        label_path = os.path.join(annotations_dir, f"{record_name}_labels.npy")

        try:
            spec = np.load(spec_path)  # shape (20, 80)
            labels = np.load(label_path)  # shape (80,)
            all_specs.append(spec)
            all_labels.append(labels)
        except Exception as e:
            print(f"Error loading {record_name}: {e}")

    return all_specs, all_labels

from collections import defaultdict
from sklearn.metrics import confusion_matrix
import numpy as np

# %%
#Input (B, T, 20) → Linear → (B, T, 40)
        #       → Transformer → (B, T, 40)
          #     → Linear Classifier → (B, T, 4)

# === Transformer Model ===
class LatentClassifier(nn.Module):
    def  __init__(self, input_dim=40, model_dim=20, num_classes=4, nhead=2, num_layers=2):
        super().__init__()
        self.input_proj = nn.Linear(input_dim, model_dim)

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=model_dim,
            nhead=nhead,
            batch_first=True
        )
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)

        self.classifier = nn.Linear(model_dim, num_classes)

    def forward(self, x):  # x: (batch, seq_len, input_dim)
        x = self.input_proj(x)         # -> (batch, seq_len, model_dim)
        x = self.encoder(x)            # -> (batch, seq_len, model_dim)
        out = self.classifier(x)       # -> (batch, seq_len, num_classes)
        return out
    

import torch
import torch.nn as nn
# One alternative
class LatentClassifier_Pos(nn.Module):
    def __init__(self, input_dim=40, model_dim=20, num_classes=4, nhead=10, num_layers=2, max_len=512):
        super().__init__()

        self.input_proj = nn.Linear(input_dim, model_dim)

        # === Learnable Positional Encoding ===
        self.positional_encoding = nn.Parameter(torch.randn(1, max_len, model_dim))

        # === Transformer Encoder ===
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=model_dim,
            nhead=nhead,
            batch_first=True
        )
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)

        self.classifier = nn.Linear(model_dim, num_classes)

    def forward(self, x):  # x: (batch, seq_len, input_dim)
        B, T, _ = x.size()
        x = self.input_proj(x)                    # → (B, T, model_dim)

        # Add positional encoding (truncate or pad as needed)
        x = x + self.positional_encoding[:, :T, :]  # → (B, T, model_dim)

        x = self.encoder(x)                       # → (B, T, model_dim)
        out = self.classifier(x)                  # → (B, T, num_classes)
        return out
    
    
    
def train_one_epoch(model, dataloader, optimizer, device, num_classes=4):
    model.train()
    criterion = nn.CrossEntropyLoss()
    total_loss = 0

    for inputs, targets in dataloader:
        inputs, targets = inputs.to(device), targets.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs.view(-1, num_classes), targets.view(-1))
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    print(f"✅ Training Loss: {total_loss / len(dataloader):.4f}")
    return total_loss / len(dataloader);

# %%
from collections import defaultdict
from sklearn.metrics import confusion_matrix

def evaluate_model(model, dataloader, device, num_classes=4,  epoch=0):
    model.eval()
    all_preds = []
    all_targets = []

    with torch.no_grad():
        for inputs, targets in dataloader:
            inputs, targets = inputs.to(device), targets.to(device)

            outputs = model(inputs)
            preds = outputs.argmax(dim=-1)

            all_preds.append(preds.cpu().view(-1))
            all_targets.append(targets.cpu().view(-1))

    preds_flat = torch.cat(all_preds).numpy()
    targets_flat = torch.cat(all_targets).numpy()

    # Accuracy
    class_correct = defaultdict(int)
    class_total = defaultdict(int)

    for c in range(num_classes):
        mask = targets_flat == c
        class_total[c] += mask.sum()
        class_correct[c] += (preds_flat[mask] == c).sum()

    total_correct = (preds_flat == targets_flat).sum()
    total_count = len(targets_flat)

    print(f"\n📊 Validation Accuracy Report")
    print(f"  Overall Accuracy: {100 * total_correct / total_count:.2f}%")

    for c in range(num_classes):
        if class_total[c] > 0:
            acc = 100 * class_correct[c] / class_total[c]
            label_name = ["background", "p_wave", "qrs", "t_wave"][c]
            print(f"  Class {c} ({label_name}): {acc:.2f}%")
        else:
            print(f"  Class {c}: No samples")

    # Confusion matrix
    cm = confusion_matrix(targets_flat, preds_flat, labels=list(range(num_classes)))
    print("\n  Confusion Matrix (rows = true, cols = predicted):")
    print(cm)
        # Plot heatmap
    class_names = ["background", "p_wave", "qrs", "t_wave"]
    #plot_confusion_matrix(cm, class_names, epoch, save_path=f"confusion_matrix_epoch_{epoch}.png")

    return 100 * total_correct / total_count  # <== return this value

# %%
def save_model(model, path="best_model.pt"):
    torch.save(model.state_dict(), path)
    print(f"📦 Model saved to: {path}")

# %%
if __name__ == "__main__":
    base_dir = "C:\\Users\\jorge\\Desktop\\ECG_PROJECT\\OnGoingDataset\\SpectrogramDataset"
    specs, labels = load_dataset(base_dir)

    # Split into train/val
    from sklearn.model_selection import train_test_split
    train_specs, val_specs, train_labels, val_labels = train_test_split(
        specs, labels, test_size=0.2, random_state=42, shuffle=True
    )

    train_dataset = SpectrogramDataset(train_specs, train_labels)
    val_dataset = SpectrogramDataset(val_specs, val_labels)

    
    print(train_specs[0].shape)
    
    train_loader = DataLoader(train_dataset, batch_size=1, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=1, shuffle=False)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    model = LatentClassifier().to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

    best_accuracy = 0.0
    epochs_without_improvement = 0
    patience = 10  # Stop if no improvement after 3 epochs
    train_losses = []
    val_accuracies = []
    
    for epoch in range(500):
        print(f"\n🔁 Epoch {epoch + 1}")
        loss = train_one_epoch(model, train_loader, optimizer, device)
        val_accuracy = evaluate_model(model, val_loader, device, epoch=epoch + 1)

        train_losses.append(loss)
        val_accuracies.append(val_accuracy)
        # Early stopping check
        if val_accuracy > best_accuracy:
            best_accuracy = val_accuracy
            epochs_without_improvement = 0
            save_model(model, "best_model.pt")
        else:
            epochs_without_improvement += 1
            print(f"⏳ No improvement for {epochs_without_improvement} epoch(s).")

        if epochs_without_improvement >= patience:
            print(f"\n🛑 Early stopping: no improvement after {patience} epochs.")
            break

plot_training_curves(train_losses, val_accuracies)
# Out:
# (40, 2500)
#
# 🔁 Epoch 1
# ✅ Training Loss: 0.7655
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 75.44%
#   Class 0 (background): 95.63%
#   Class 1 (p_wave): 0.00%
#   Class 2 (qrs): 80.78%
#   Class 3 (t_wave): 6.35%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[66776     0  2734   321]
#  [ 6225     0    71    32]
#  [ 1846     0  7761     0]
#  [12822     0   508   904]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 2
# ✅ Training Loss: 0.6179
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 78.91%
#   Class 0 (background): 90.15%
#   Class 1 (p_wave): 10.40%
#   Class 2 (qrs): 90.54%
#   Class 3 (t_wave): 46.40%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[62950   461  2914  3506]
#  [ 5110   658    91   469]
#  [  904     0  8698     5]
#  [ 7520    13    96  6605]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 3
# ✅ Training Loss: 0.5609
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 79.42%
#   Class 0 (background): 90.85%
#   Class 1 (p_wave): 17.53%
#   Class 2 (qrs): 91.20%
#   Class 3 (t_wave): 42.95%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[63439   763  2807  2822]
#  [ 4831  1109    44   344]
#  [  845     0  8762     0]
#  [ 8016     9    95  6114]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 4
# ✅ Training Loss: 0.5255
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 80.22%
#   Class 0 (background): 88.55%
#   Class 1 (p_wave): 35.03%
#   Class 2 (qrs): 90.21%
#   Class 3 (t_wave): 52.73%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61835  1535  2650  3811]
#  [ 3780  2217    32   299]
#  [  941     0  8666     0]
#  [ 6519    72   137  7506]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 5
# ✅ Training Loss: 0.5012
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 80.10%
#   Class 0 (background): 90.96%
#   Class 1 (p_wave): 27.59%
#   Class 2 (qrs): 89.01%
#   Class 3 (t_wave): 44.19%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[63517  1196  2456  2662]
#  [ 4369  1746    15   198]
#  [ 1056     0  8551     0]
#  [ 7858     3    83  6290]]
# ⏳ No improvement for 1 epoch(s).
#
# 🔁 Epoch 6
# ✅ Training Loss: 0.4823
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 80.23%
#   Class 0 (background): 91.27%
#   Class 1 (p_wave): 18.14%
#   Class 2 (qrs): 87.92%
#   Class 3 (t_wave): 48.48%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[63734   629  2415  3053]
#  [ 4958  1148    13   209]
#  [ 1161     0  8446     0]
#  [ 7125     0   208  6901]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 7
# ✅ Training Loss: 0.4690
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 80.72%
#   Class 0 (background): 88.96%
#   Class 1 (p_wave): 27.40%
#   Class 2 (qrs): 92.12%
#   Class 3 (t_wave): 56.34%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[62119  1087  2830  3795]
#  [ 4328  1734    28   238]
#  [  757     0  8850     0]
#  [ 6041     3   170  8020]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 8
# ✅ Training Loss: 0.4582
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 80.52%
#   Class 0 (background): 89.87%
#   Class 1 (p_wave): 16.97%
#   Class 2 (qrs): 90.72%
#   Class 3 (t_wave): 56.04%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[62757   615  2677  3782]
#  [ 5053  1074    12   189]
#  [  892     0  8715     0]
#  [ 6100     2   155  7977]]
# ⏳ No improvement for 1 epoch(s).
#
# 🔁 Epoch 9
# ✅ Training Loss: 0.4470
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 80.62%
#   Class 0 (background): 87.47%
#   Class 1 (p_wave): 42.56%
#   Class 2 (qrs): 92.10%
#   Class 3 (t_wave): 56.24%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61079  1828  2973  3951]
#  [ 3367  2693    47   221]
#  [  759     0  8848     0]
#  [ 5669     8   552  8005]]
# ⏳ No improvement for 2 epoch(s).
#
# 🔁 Epoch 10
# ✅ Training Loss: 0.4416
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 80.91%
#   Class 0 (background): 88.72%
#   Class 1 (p_wave): 44.22%
#   Class 2 (qrs): 89.97%
#   Class 3 (t_wave): 52.82%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61955  1955  2628  3293]
#  [ 3408  2798    15   107]
#  [  964     0  8643     0]
#  [ 6324     9   383  7518]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 11
# ✅ Training Loss: 0.4343
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 81.09%
#   Class 0 (background): 89.09%
#   Class 1 (p_wave): 40.77%
#   Class 2 (qrs): 85.79%
#   Class 3 (t_wave): 56.61%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[62212  1644  2188  3787]
#  [ 3617  2580     6   125]
#  [ 1365     0  8242     0]
#  [ 6039    10   127  8058]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 12
# ✅ Training Loss: 0.4315
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 81.11%
#   Class 0 (background): 89.99%
#   Class 1 (p_wave): 38.53%
#   Class 2 (qrs): 90.13%
#   Class 3 (t_wave): 50.38%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[62842  1505  2556  2928]
#  [ 3781  2438    13    96]
#  [  948     0  8659     0]
#  [ 6870     4   189  7171]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 13
# ✅ Training Loss: 0.4264
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 81.40%
#   Class 0 (background): 87.97%
#   Class 1 (p_wave): 44.20%
#   Class 2 (qrs): 91.01%
#   Class 3 (t_wave): 59.27%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61427  1796  2624  3984]
#  [ 3324  2797     9   198]
#  [  864     0  8743     0]
#  [ 5705     5    87  8437]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 14
# ✅ Training Loss: 0.4208
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 80.97%
#   Class 0 (background): 86.77%
#   Class 1 (p_wave): 50.21%
#   Class 2 (qrs): 92.06%
#   Class 3 (t_wave): 58.70%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[60593  2212  2881  4145]
#  [ 2877  3177    75   199]
#  [  763     0  8844     0]
#  [ 5466     7   405  8356]]
# ⏳ No improvement for 1 epoch(s).
#
# 🔁 Epoch 15
# ✅ Training Loss: 0.4174
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 81.25%
#   Class 0 (background): 89.76%
#   Class 1 (p_wave): 33.42%
#   Class 2 (qrs): 85.47%
#   Class 3 (t_wave): 57.93%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[62681  1219  2122  3809]
#  [ 4100  2115     1   112]
#  [ 1396     0  8211     0]
#  [ 5948     4    36  8246]]
# ⏳ No improvement for 2 epoch(s).
#
# 🔁 Epoch 16
# ✅ Training Loss: 0.4147
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 81.74%
#   Class 0 (background): 87.65%
#   Class 1 (p_wave): 51.74%
#   Class 2 (qrs): 88.81%
#   Class 3 (t_wave): 61.31%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61204  2094  2399  4134]
#  [ 2884  3274    22   148]
#  [ 1075     0  8532     0]
#  [ 5377     7   123  8727]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 17
# ✅ Training Loss: 0.4101
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 81.69%
#   Class 0 (background): 86.30%
#   Class 1 (p_wave): 55.15%
#   Class 2 (qrs): 91.69%
#   Class 3 (t_wave): 64.14%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[60264  2382  2689  4496]
#  [ 2694  3490     4   140]
#  [  798     0  8809     0]
#  [ 5007     6    92  9129]]
# ⏳ No improvement for 1 epoch(s).
#
# 🔁 Epoch 18
# ✅ Training Loss: 0.4081
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 81.65%
#   Class 0 (background): 88.09%
#   Class 1 (p_wave): 51.98%
#   Class 2 (qrs): 90.27%
#   Class 3 (t_wave): 57.43%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61512  2118  2528  3673]
#  [ 2899  3289    23   117]
#  [  935     0  8672     0]
#  [ 5906     7   147  8174]]
# ⏳ No improvement for 2 epoch(s).
#
# 🔁 Epoch 19
# ✅ Training Loss: 0.4050
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 81.91%
#   Class 0 (background): 86.58%
#   Class 1 (p_wave): 56.02%
#   Class 2 (qrs): 90.56%
#   Class 3 (t_wave): 64.64%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[60459  2385  2477  4510]
#  [ 2617  3545     0   166]
#  [  907     0  8700     0]
#  [ 4956     6    71  9201]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 20
# ✅ Training Loss: 0.4016
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 81.58%
#   Class 0 (background): 89.05%
#   Class 1 (p_wave): 36.03%
#   Class 2 (qrs): 90.78%
#   Class 3 (t_wave): 58.97%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[62183  1208  2623  3817]
#  [ 3921  2280     8   119]
#  [  886     0  8721     0]
#  [ 5684     3   153  8394]]
# ⏳ No improvement for 1 epoch(s).
#
# 🔁 Epoch 21
# ✅ Training Loss: 0.4007
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 81.81%
#   Class 0 (background): 87.18%
#   Class 1 (p_wave): 52.45%
#   Class 2 (qrs): 89.45%
#   Class 3 (t_wave): 63.36%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[60882  2074  2385  4490]
#  [ 2861  3319     3   145]
#  [ 1014     0  8593     0]
#  [ 5171     4    40  9019]]
# ⏳ No improvement for 2 epoch(s).
#
# 🔁 Epoch 22
# ✅ Training Loss: 0.3955
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 81.77%
#   Class 0 (background): 85.28%
#   Class 1 (p_wave): 62.18%
#   Class 2 (qrs): 89.45%
#   Class 3 (t_wave): 68.05%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[59553  2734  2383  5161]
#  [ 2207  3935     3   183]
#  [ 1014     0  8593     0]
#  [ 4489     7    52  9686]]
# ⏳ No improvement for 3 epoch(s).
#
# 🔁 Epoch 23
# ✅ Training Loss: 0.3949
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.09%
#   Class 0 (background): 87.04%
#   Class 1 (p_wave): 59.77%
#   Class 2 (qrs): 88.00%
#   Class 3 (t_wave): 63.73%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[60782  2523  2235  4291]
#  [ 2440  3782     0   106]
#  [ 1153     0  8454     0]
#  [ 5135     8    20  9071]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 24
# ✅ Training Loss: 0.3936
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.12%
#   Class 0 (background): 87.38%
#   Class 1 (p_wave): 53.62%
#   Class 2 (qrs): 91.01%
#   Class 3 (t_wave): 63.03%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61016  2037  2491  4287]
#  [ 2817  3393     0   118]
#  [  864     0  8743     0]
#  [ 5227     4    32  8971]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 25
# ✅ Training Loss: 0.3900
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.14%
#   Class 0 (background): 87.43%
#   Class 1 (p_wave): 53.10%
#   Class 2 (qrs): 89.10%
#   Class 3 (t_wave): 64.41%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61052  1962  2358  4459]
#  [ 2844  3360     0   124]
#  [ 1047     0  8560     0]
#  [ 5034     4    28  9168]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 26
# ✅ Training Loss: 0.3897
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.31%
#   Class 0 (background): 87.23%
#   Class 1 (p_wave): 56.89%
#   Class 2 (qrs): 89.80%
#   Class 3 (t_wave): 64.42%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[60911  2173  2387  4360]
#  [ 2613  3600     1   114]
#  [  980     0  8627     0]
#  [ 5021     7    37  9169]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 27
# ✅ Training Loss: 0.3876
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.32%
#   Class 0 (background): 87.59%
#   Class 1 (p_wave): 55.96%
#   Class 2 (qrs): 88.04%
#   Class 3 (t_wave): 64.35%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61163  2117  2268  4283]
#  [ 2692  3541     3    92]
#  [ 1149     0  8458     0]
#  [ 5033     5    36  9160]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 28
# ✅ Training Loss: 0.3873
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.45%
#   Class 0 (background): 89.10%
#   Class 1 (p_wave): 52.35%
#   Class 2 (qrs): 88.97%
#   Class 3 (t_wave): 58.78%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[62222  1840  2264  3505]
#  [ 2968  3313     0    47]
#  [ 1060     0  8547     0]
#  [ 5857     3     7  8367]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 29
# ✅ Training Loss: 0.3852
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.17%
#   Class 0 (background): 87.60%
#   Class 1 (p_wave): 52.32%
#   Class 2 (qrs): 93.02%
#   Class 3 (t_wave): 61.49%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61175  1871  2772  4013]
#  [ 2944  3311     2    71]
#  [  671     0  8936     0]
#  [ 5434     4    43  8753]]
# ⏳ No improvement for 1 epoch(s).
#
# 🔁 Epoch 30
# ✅ Training Loss: 0.3835
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.29%
#   Class 0 (background): 88.39%
#   Class 1 (p_wave): 44.79%
#   Class 2 (qrs): 90.39%
#   Class 3 (t_wave): 63.57%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61722  1501  2403  4205]
#  [ 3425  2834     0    69]
#  [  923     0  8684     0]
#  [ 5164     3    19  9048]]
# ⏳ No improvement for 2 epoch(s).
#
# 🔁 Epoch 31
# ✅ Training Loss: 0.3810
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.40%
#   Class 0 (background): 85.29%
#   Class 1 (p_wave): 66.21%
#   Class 2 (qrs): 89.34%
#   Class 3 (t_wave): 70.75%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[59559  2836  2333  5103]
#  [ 1987  4190     0   151]
#  [ 1024     0  8583     0]
#  [ 4132     6    25 10071]]
# ⏳ No improvement for 3 epoch(s).
#
# 🔁 Epoch 32
# ✅ Training Loss: 0.3799
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.03%
#   Class 0 (background): 84.74%
#   Class 1 (p_wave): 63.91%
#   Class 2 (qrs): 91.82%
#   Class 3 (t_wave): 70.23%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[59173  2662  2559  5437]
#  [ 2147  4044     0   137]
#  [  786     0  8821     0]
#  [ 4200     5    33  9996]]
# ⏳ No improvement for 4 epoch(s).
#
# 🔁 Epoch 33
# ✅ Training Loss: 0.3791
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.58%
#   Class 0 (background): 89.34%
#   Class 1 (p_wave): 49.21%
#   Class 2 (qrs): 87.37%
#   Class 3 (t_wave): 61.02%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[62387  1568  2140  3736]
#  [ 3165  3114     0    49]
#  [ 1213     0  8394     0]
#  [ 5546     3     0  8685]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 34
# ✅ Training Loss: 0.3778
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.70%
#   Class 0 (background): 88.47%
#   Class 1 (p_wave): 56.43%
#   Class 2 (qrs): 87.65%
#   Class 3 (t_wave): 62.72%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61782  1969  2164  3916]
#  [ 2710  3571     0    47]
#  [ 1186     0  8421     0]
#  [ 5299     4     4  8927]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 35
# ✅ Training Loss: 0.3770
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.48%
#   Class 0 (background): 88.76%
#   Class 1 (p_wave): 53.51%
#   Class 2 (qrs): 87.55%
#   Class 3 (t_wave): 61.13%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61981  1831  2203  3816]
#  [ 2887  3386     2    53]
#  [ 1196     0  8411     0]
#  [ 5522     3     8  8701]]
# ⏳ No improvement for 1 epoch(s).
#
# 🔁 Epoch 36
# ✅ Training Loss: 0.3767
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.83%
#   Class 0 (background): 87.86%
#   Class 1 (p_wave): 54.98%
#   Class 2 (qrs): 89.86%
#   Class 3 (t_wave): 65.79%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61351  1774  2339  4367]
#  [ 2755  3479     0    94]
#  [  974     0  8633     0]
#  [ 4858     4     8  9364]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 37
# ✅ Training Loss: 0.3737
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.77%
#   Class 0 (background): 88.64%
#   Class 1 (p_wave): 52.18%
#   Class 2 (qrs): 89.66%
#   Class 3 (t_wave): 62.95%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61898  1719  2307  3907]
#  [ 2971  3302     0    55]
#  [  993     0  8614     0]
#  [ 5263     3     8  8960]]
# ⏳ No improvement for 1 epoch(s).
#
# 🔁 Epoch 38
# ✅ Training Loss: 0.3734
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.51%
#   Class 0 (background): 89.33%
#   Class 1 (p_wave): 46.62%
#   Class 2 (qrs): 89.25%
#   Class 3 (t_wave): 60.45%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[62380  1474  2268  3709]
#  [ 3344  2950     0    34]
#  [ 1033     0  8574     0]
#  [ 5620     3     7  8604]]
# ⏳ No improvement for 2 epoch(s).
#
# 🔁 Epoch 39
# ✅ Training Loss: 0.3720
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.74%
#   Class 0 (background): 87.12%
#   Class 1 (p_wave): 63.84%
#   Class 2 (qrs): 89.34%
#   Class 3 (t_wave): 65.18%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[60838  2492  2296  4205]
#  [ 2237  4040     0    51]
#  [ 1024     0  8583     0]
#  [ 4933    12    11  9278]]
# ⏳ No improvement for 3 epoch(s).
#
# 🔁 Epoch 40
# ✅ Training Loss: 0.3730
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.73%
#   Class 0 (background): 87.76%
#   Class 1 (p_wave): 59.70%
#   Class 2 (qrs): 90.21%
#   Class 3 (t_wave): 63.28%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61282  2134  2361  4054]
#  [ 2479  3778     0    71]
#  [  941     0  8666     0]
#  [ 5217     4     6  9007]]
# ⏳ No improvement for 4 epoch(s).
#
# 🔁 Epoch 41
# ✅ Training Loss: 0.3689
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.55%
#   Class 0 (background): 86.73%
#   Class 1 (p_wave): 64.08%
#   Class 2 (qrs): 89.76%
#   Class 3 (t_wave): 65.37%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[60566  2547  2278  4440]
#  [ 2194  4055     0    79]
#  [  984     0  8623     0]
#  [ 4926     3     0  9305]]
# ⏳ No improvement for 5 epoch(s).
#
# 🔁 Epoch 42
# ✅ Training Loss: 0.3686
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.72%
#   Class 0 (background): 86.90%
#   Class 1 (p_wave): 63.86%
#   Class 2 (qrs): 88.98%
#   Class 3 (t_wave): 66.35%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[60684  2357  2238  4552]
#  [ 2226  4041     0    61]
#  [ 1059     0  8548     0]
#  [ 4776     6     8  9444]]
# ⏳ No improvement for 6 epoch(s).
#
# 🔁 Epoch 43
# ✅ Training Loss: 0.3673
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.53%
#   Class 0 (background): 88.61%
#   Class 1 (p_wave): 57.70%
#   Class 2 (qrs): 87.49%
#   Class 3 (t_wave): 60.43%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61875  2055  2161  3740]
#  [ 2612  3651     0    65]
#  [ 1202     0  8405     0]
#  [ 5629     4     0  8601]]
# ⏳ No improvement for 7 epoch(s).
#
# 🔁 Epoch 44
# ✅ Training Loss: 0.3662
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 83.06%
#   Class 0 (background): 88.30%
#   Class 1 (p_wave): 55.66%
#   Class 2 (qrs): 88.70%
#   Class 3 (t_wave): 65.77%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61658  1816  2220  4137]
#  [ 2752  3522     0    54]
#  [ 1086     0  8521     0]
#  [ 4866     3     3  9362]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 45
# ✅ Training Loss: 0.3649
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.57%
#   Class 0 (background): 89.48%
#   Class 1 (p_wave): 44.36%
#   Class 2 (qrs): 89.14%
#   Class 3 (t_wave): 61.23%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[62484  1376  2281  3690]
#  [ 3472  2807     0    49]
#  [ 1043     0  8564     0]
#  [ 5508     4     6  8716]]
# ⏳ No improvement for 1 epoch(s).
#
# 🔁 Epoch 46
# ✅ Training Loss: 0.3630
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.56%
#   Class 0 (background): 86.06%
#   Class 1 (p_wave): 64.06%
#   Class 2 (qrs): 90.74%
#   Class 3 (t_wave): 68.08%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[60100  2494  2449  4788]
#  [ 2183  4054     9    82]
#  [  890     0  8717     0]
#  [ 4529     4    11  9690]]
# ⏳ No improvement for 2 epoch(s).
#
# 🔁 Epoch 47
# ✅ Training Loss: 0.3622
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 83.25%
#   Class 0 (background): 87.46%
#   Class 1 (p_wave): 59.05%
#   Class 2 (qrs): 91.68%
#   Class 3 (t_wave): 67.72%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61071  1939  2490  4331]
#  [ 2541  3737     0    50]
#  [  799     0  8808     0]
#  [ 4590     3     2  9639]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 48
# ✅ Training Loss: 0.3628
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.80%
#   Class 0 (background): 89.06%
#   Class 1 (p_wave): 57.68%
#   Class 2 (qrs): 91.11%
#   Class 3 (t_wave): 57.70%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[62188  1956  2442  3245]
#  [ 2652  3650     0    26]
#  [  854     0  8753     0]
#  [ 6013     3     5  8213]]
# ⏳ No improvement for 1 epoch(s).
#
# 🔁 Epoch 49
# ✅ Training Loss: 0.3624
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.68%
#   Class 0 (background): 85.04%
#   Class 1 (p_wave): 67.84%
#   Class 2 (qrs): 93.82%
#   Class 3 (t_wave): 70.19%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[59382  2675  2853  4921]
#  [ 1967  4293     0    68]
#  [  594     0  9013     0]
#  [ 4219     5    19  9991]]
# ⏳ No improvement for 2 epoch(s).
#
# 🔁 Epoch 50
# ✅ Training Loss: 0.3613
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.86%
#   Class 0 (background): 89.05%
#   Class 1 (p_wave): 44.85%
#   Class 2 (qrs): 90.52%
#   Class 3 (t_wave): 64.25%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[62183  1293  2367  3988]
#  [ 3444  2838     0    46]
#  [  911     0  8696     0]
#  [ 5078     3     8  9145]]
# ⏳ No improvement for 3 epoch(s).
#
# 🔁 Epoch 51
# ✅ Training Loss: 0.3613
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 83.17%
#   Class 0 (background): 87.22%
#   Class 1 (p_wave): 65.49%
#   Class 2 (qrs): 89.45%
#   Class 3 (t_wave): 66.90%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[60910  2448  2271  4202]
#  [ 2136  4144     0    48]
#  [ 1014     0  8593     0]
#  [ 4704     4     3  9523]]
# ⏳ No improvement for 4 epoch(s).
#
# 🔁 Epoch 52
# ✅ Training Loss: 0.3589
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 83.04%
#   Class 0 (background): 87.59%
#   Class 1 (p_wave): 56.91%
#   Class 2 (qrs): 91.77%
#   Class 3 (t_wave): 66.45%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61167  1900  2551  4213]
#  [ 2666  3601     3    58]
#  [  791     0  8816     0]
#  [ 4755     6    15  9458]]
# ⏳ No improvement for 5 epoch(s).
#
# 🔁 Epoch 53
# ✅ Training Loss: 0.3589
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.78%
#   Class 0 (background): 86.76%
#   Class 1 (p_wave): 64.21%
#   Class 2 (qrs): 90.96%
#   Class 3 (t_wave): 66.01%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[60585  2402  2492  4352]
#  [ 2200  4063    21    44]
#  [  868     0  8739     0]
#  [ 4777     8    53  9396]]
# ⏳ No improvement for 6 epoch(s).
#
# 🔁 Epoch 54
# ✅ Training Loss: 0.3578
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 83.11%
#   Class 0 (background): 88.03%
#   Class 1 (p_wave): 51.01%
#   Class 2 (qrs): 92.11%
#   Class 3 (t_wave): 67.17%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61473  1525  2570  4263]
#  [ 3030  3228     0    70]
#  [  758     0  8849     0]
#  [ 4654     3    16  9561]]
# ⏳ No improvement for 7 epoch(s).
#
# 🔁 Epoch 55
# ✅ Training Loss: 0.3558
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.80%
#   Class 0 (background): 87.72%
#   Class 1 (p_wave): 53.43%
#   Class 2 (qrs): 92.31%
#   Class 3 (t_wave): 65.29%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61259  1668  2565  4339]
#  [ 2894  3381     0    53]
#  [  739     0  8868     0]
#  [ 4934     3     4  9293]]
# ⏳ No improvement for 8 epoch(s).
#
# 🔁 Epoch 56
# ✅ Training Loss: 0.3557
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 83.40%
#   Class 0 (background): 87.37%
#   Class 1 (p_wave): 63.64%
#   Class 2 (qrs): 90.18%
#   Class 3 (t_wave): 68.17%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61008  2150  2305  4368]
#  [ 2232  4027     0    69]
#  [  943     0  8664     0]
#  [ 4524     4     2  9704]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 57
# ✅ Training Loss: 0.3550
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 83.00%
#   Class 0 (background): 89.89%
#   Class 1 (p_wave): 48.78%
#   Class 2 (qrs): 87.03%
#   Class 3 (t_wave): 61.70%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[62770  1420  2086  3555]
#  [ 3218  3087     0    23]
#  [ 1246     0  8361     0]
#  [ 5449     3     0  8782]]
# ⏳ No improvement for 1 epoch(s).
#
# 🔁 Epoch 58
# ✅ Training Loss: 0.3551
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.88%
#   Class 0 (background): 88.40%
#   Class 1 (p_wave): 52.73%
#   Class 2 (qrs): 91.86%
#   Class 3 (t_wave): 63.10%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61733  1611  2529  3958]
#  [ 2949  3337     0    42]
#  [  782     0  8825     0]
#  [ 5243     4     5  8982]]
# ⏳ No improvement for 2 epoch(s).
#
# 🔁 Epoch 59
# ✅ Training Loss: 0.3537
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 83.03%
#   Class 0 (background): 88.41%
#   Class 1 (p_wave): 50.81%
#   Class 2 (qrs): 89.88%
#   Class 3 (t_wave): 66.39%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61735  1527  2276  4293]
#  [ 3060  3215     0    53]
#  [  972     0  8635     0]
#  [ 4780     4     0  9450]]
# ⏳ No improvement for 3 epoch(s).
#
# 🔁 Epoch 60
# ✅ Training Loss: 0.3524
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 83.25%
#   Class 0 (background): 89.03%
#   Class 1 (p_wave): 56.86%
#   Class 2 (qrs): 90.09%
#   Class 3 (t_wave): 61.97%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[62171  1797  2334  3529]
#  [ 2702  3598     0    28]
#  [  952     0  8655     0]
#  [ 5406     4     3  8821]]
# ⏳ No improvement for 4 epoch(s).
#
# 🔁 Epoch 61
# ✅ Training Loss: 0.3516
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.87%
#   Class 0 (background): 87.31%
#   Class 1 (p_wave): 67.37%
#   Class 2 (qrs): 90.70%
#   Class 3 (t_wave): 62.72%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[60967  2549  2385  3930]
#  [ 2033  4263     0    32]
#  [  893     0  8714     0]
#  [ 5295     7     5  8927]]
# ⏳ No improvement for 5 epoch(s).
#
# 🔁 Epoch 62
# ✅ Training Loss: 0.3513
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.73%
#   Class 0 (background): 89.16%
#   Class 1 (p_wave): 53.14%
#   Class 2 (qrs): 87.43%
#   Class 3 (t_wave): 61.17%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[62264  1641  2117  3809]
#  [ 2933  3363     0    32]
#  [ 1208     0  8399     0]
#  [ 5518     5     4  8707]]
# ⏳ No improvement for 6 epoch(s).
#
# 🔁 Epoch 63
# ✅ Training Loss: 0.3505
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 83.06%
#   Class 0 (background): 87.74%
#   Class 1 (p_wave): 60.40%
#   Class 2 (qrs): 91.11%
#   Class 3 (t_wave): 64.71%
#   Confusion Matrix (rows = true, cols = predicted):
# [[61273  1952  2400  4206]
#  [ 2463  3822     0    43]
#  [  854     0  8753     0]
#  [ 5016     4     3  9211]]
# ⏳ No improvement for 7 epoch(s).
#
# 🔁 Epoch 64
# ✅ Training Loss: 0.3490
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 83.17%
#   Class 0 (background): 87.23%
#   Class 1 (p_wave): 62.20%
#   Class 2 (qrs): 90.00%
#   Class 3 (t_wave): 67.94%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[60914  2152  2336  4429]
#  [ 2347  3936     1    44]
#  [  961     0  8646     0]
#  [ 4546    11     6  9671]]
# ⏳ No improvement for 8 epoch(s).
#
# 🔁 Epoch 65
# ✅ Training Loss: 0.3480
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 83.56%
#   Class 0 (background): 88.34%
#   Class 1 (p_wave): 58.96%
#   Class 2 (qrs): 89.20%
#   Class 3 (t_wave): 67.28%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61687  1873  2265  4006]
#  [ 2570  3731     0    27]
#  [ 1038     0  8569     0]
#  [ 4647     5     6  9576]]
# 📦 Model saved to: best_model.pt
#
# 🔁 Epoch 66
# ✅ Training Loss: 0.3501
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 83.27%
#   Class 0 (background): 86.02%
#   Class 1 (p_wave): 66.86%
#   Class 2 (qrs): 90.84%
#   Class 3 (t_wave): 72.00%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[60068  2373  2449  4941]
#  [ 2046  4231     4    47]
#  [  880     0  8727     0]
#  [ 3934     7    45 10248]]
# ⏳ No improvement for 1 epoch(s).
#
# 🔁 Epoch 67
# ✅ Training Loss: 0.3475
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 83.00%
#   Class 0 (background): 86.42%
#   Class 1 (p_wave): 69.58%
#   Class 2 (qrs): 90.67%
#   Class 3 (t_wave): 66.95%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[60351  2610  2410  4460]
#  [ 1883  4403     1    41]
#  [  896     0  8711     0]
#  [ 4676    16    12  9530]]
# ⏳ No improvement for 2 epoch(s).
#
# 🔁 Epoch 68
# ✅ Training Loss: 0.3484
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 83.48%
#   Class 0 (background): 88.62%
#   Class 1 (p_wave): 59.26%
#   Class 2 (qrs): 91.64%
#   Class 3 (t_wave): 63.48%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61886  1859  2438  3648]
#  [ 2547  3750     0    31]
#  [  803     0  8804     0]
#  [ 5192     4     2  9036]]
# ⏳ No improvement for 3 epoch(s).
#
# 🔁 Epoch 69
# ✅ Training Loss: 0.3451
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 82.82%
#   Class 0 (background): 85.04%
#   Class 1 (p_wave): 72.17%
#   Class 2 (qrs): 89.68%
#   Class 3 (t_wave): 72.00%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[59385  2892  2277  5277]
#  [ 1664  4567     2    95]
#  [  991     0  8616     0]
#  [ 3977     8     1 10248]]
# ⏳ No improvement for 4 epoch(s).
#
# 🔁 Epoch 70
# ✅ Training Loss: 0.3461
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 83.48%
#   Class 0 (background): 88.85%
#   Class 1 (p_wave): 56.68%
#   Class 2 (qrs): 91.31%
#   Class 3 (t_wave): 63.76%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[62046  1681  2416  3688]
#  [ 2721  3587     0    20]
#  [  835     0  8772     0]
#  [ 5155     2     2  9075]]
# ⏳ No improvement for 5 epoch(s).
#
# 🔁 Epoch 71
# ✅ Training Loss: 0.3450
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 83.06%
#   Class 0 (background): 85.46%
#   Class 1 (p_wave): 68.76%
#   Class 2 (qrs): 91.25%
#   Class 3 (t_wave): 72.14%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[59675  2589  2471  5096]
#  [ 1907  4351     1    69]
#  [  841     0  8766     0]
#  [ 3950    10     6 10268]]
# ⏳ No improvement for 6 epoch(s).
#
# 🔁 Epoch 72
# ✅ Training Loss: 0.3448
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 83.31%
#   Class 0 (background): 89.01%
#   Class 1 (p_wave): 58.12%
#   Class 2 (qrs): 89.15%
#   Class 3 (t_wave): 62.63%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[62157  1810  2186  3678]
#  [ 2627  3678     0    23]
#  [ 1042     0  8565     0]
#  [ 5317     2     0  8915]]
# ⏳ No improvement for 7 epoch(s).
#
# 🔁 Epoch 73
# ✅ Training Loss: 0.3441
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 83.10%
#   Class 0 (background): 85.56%
#   Class 1 (p_wave): 71.82%
#   Class 2 (qrs): 89.68%
#   Class 3 (t_wave): 71.63%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[59747  2954  2277  4853]
#  [ 1721  4545     0    62]
#  [  991     0  8616     0]
#  [ 4032     4     2 10196]]
# ⏳ No improvement for 8 epoch(s).
#
# 🔁 Epoch 74
# ✅ Training Loss: 0.3436
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 83.28%
#   Class 0 (background): 88.69%
#   Class 1 (p_wave): 61.25%
#   Class 2 (qrs): 87.50%
#   Class 3 (t_wave): 63.66%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61934  2036  2089  3772]
#  [ 2422  3876     0    30]
#  [ 1201     0  8406     0]
#  [ 5164     6     2  9062]]
# ⏳ No improvement for 9 epoch(s).
#
# 🔁 Epoch 75
# ✅ Training Loss: 0.3427
#
# 📊 Validation Accuracy Report
#   Overall Accuracy: 83.23%
#   Class 0 (background): 87.88%
#   Class 1 (p_wave): 62.09%
#   Class 2 (qrs): 89.31%
#   Class 3 (t_wave): 65.72%
#
#   Confusion Matrix (rows = true, cols = predicted):
# [[61370  2040  2246  4175]
#  [ 2365  3929     0    34]
#  [ 1027     0  8580     0]
#  [ 4875     4     1  9354]]
# ⏳ No improvement for 10 epoch(s).
#
# 🛑 Early stopping: no improvement after 10 epochs.
# 📈 Training curves saved: training_curves.png
